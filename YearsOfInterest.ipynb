# %%
# %run A_FunctionDefinitions.ipynb ; #Contains all definitions

# %%
gauge=8271000 #9065500 #11264500

# %%
#RUN RASTER PLOTS TO HELP SELECT YEARS OF INTEREST
fig=RasterHydrograph(gauge)
#fig = RasterPrecip(gauge,'daymet')
fig = RollingRasterPrecip(gauge,dataset='daymet',window=30)
fig = RasterTemps(gauge,'max','daymet')

# %%
#Emphasize Selected Years for plots of flow & precip
selected_years=[2001,1986,1990]  # must be in brackets, even if single year
fig=MedianFDC_selectyears(gauge,selected_years)
fig=MedianScaledFDC_selectyears(gauge,selected_years)
fig=TypicalYear_selectyears(gauge,selected_years)
fig=RollingPrcp_select(gauge,selected_years)

# %%
#Temperature is too crowded, so this shows just the first year selected with its daily min/max
selectedyear=selected_years[0]
fig = TypicalTemp_selectyear(gauge,selectedyear)
